# %%
import os
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate
from langchain_community.document_loaders import PyPDFLoader
from operator import itemgetter
from langchain_community.vectorstores import FAISS
from langchain_openai.chat_models import ChatOpenAI
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_community.llms import Ollama
from langchain_community.embeddings import OllamaEmbeddings


from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %% [markdown]
# ## Load the model and embeddings
#
# We use the llama3 70B model as the LLM and the embeddings model

# %%
model_type = 'llama'
name = 'llama3:70b'
model = Ollama(model=name)
embeddings = OllamaEmbeddings(model=name)

# %% [markdown]
# ## Create prompt

# %%
parser = StrOutputParser()

template = """
Answer the question based on the context below. If you can't 
answer the question, reply "I don't know".

Context: {context}

Question: {question}
"""

prompt = PromptTemplate.from_template(template)
prompt.format(context="Here is some context", question="Here is a question")
# Out:
# '\nAnswer the question based on the context below. If you can\'t \nanswer the question, reply "I don\'t know".\n\nContext: Here is some context\n\nQuestion: Here is a question\n'

# %% [markdown]
# ## Read the pdf and create vector store using the embeddings model

# %%
pdf_path = "1Q23-EPR-with-Tables-FINAL.pdf"
loader = PyPDFLoader(pdf_path)
pages = loader.load_and_split()

# %%
vectorstore = FAISS.from_documents(pages, embedding=embeddings)
retriever = vectorstore.as_retriever()

# %% [markdown]
# ## Create the model chain
#
# The model chain starts with the question. Using the question, the the context is extracted from the vector store. The LLM uses the context to answer the question.

# %%
chain = (
    {
        "context": itemgetter("question") | retriever,
        "question": itemgetter("question"),
    }
    | prompt
    | model
    | parser
)

# %% [markdown]
# ## Ask the questions
#
# We iterate through all the questions and feed them to the model to get the answers based on the context. The questions and the answers are displayed in the following cells.

# %%
questions = [
    ("A company produces 500 tons of plastic packaging annually and is subject to an Extended Producer Responsibility (EPR) scheme "
     "with a recovery target of 80%. How many tons of plastic packaging should the company aim to recover each year to meet the EPR requirement?"),
     "What is the report quarter and when did it end?",
    ("What are the results for the reporting quarter? Please describe in the following order using bullet points - revenue, gross margin, opex, "
     "op margin, net income, and EPS. Include both GAAP and non-GAAP numbers. Please also include quarter-over-quarter changes."),
    ("If a municipality introduces a pay-as-you-throw program as part of its EPR strategy, charging households $0.05 per pound of collected waste, "
     "calculate the cost for a household that generates 30 pounds per week."),
    "What's the OP margin for the current quarter?",
    ("Identify potential risks associated with EPR implementation, such as regulatory changes, market volatility, and technological disruptions. "
     "Develop a risk assessment framework that assigns probabilities and impacts to each identified risk factor. Propose risk mitigation strategies "
     "for minimizing the adverse effects of these risks on EPR programs and stakeholder interests."),
     "What were Gap Inc's net sales for the first quarter of fiscal 2023 and how did they compare to the previous year?",
     "How did merchandise margin change from the previous year, and what were the drivers of this change?",
     "Did Gap Inc. have an operating profit or loss, and if so, what was the amount?",
     "What were the key results from each of Gap Inc.'s brands (Old Navy, Gap, Banana Republic, and Athleta)?",
     "What is the company's outlook on net sales for the second quarter and the full fiscal year 2023?",
     "How much cash and cash equivalents did Gap, Inc. have at the end of the quarter?",
     "How does the company expect gross margin to change in Q2 and the full year compared to 2022?",
     "Did Gap Inc. pay a dividend in the first quarter, and what is their dividend strategy going forward?",
     "What are the key actions Gap Inc. is taking to execute its plan?"
]

# %%
print(f"Total number of questions: {len(questions)}\n")
answers = []
for question in questions:
    ans = chain.invoke({'question': question})
    answers.append(ans)
    print(f"Question: {question}\n")
    print(f"Answer: {ans}")
    print('\n')
# Out:
# Total number of questions: 15
#
# Question: A company produces 500 tons of plastic packaging annually and is subject to an Extended Producer Responsibility (EPR) scheme with a recovery target of 80%. How many tons of plastic packaging should the company aim to recover each year to meet the EPR requirement?
#
# Answer: Based on the provided context, I can answer your question.
#
# To meet the EPR requirement, the company should aim to recover 80% of its annual production of plastic packaging. Since it produces 500 tons annually, the recovery target would be:
#
# 500 tons x 0.8 (recovery target) = 400 tons
#
# So, the company should aim to recover 400 tons of plastic packaging each year to meet the EPR requirement.
#
#
# Question: What is the report quarter and when did it end?
#
# Answer: The report is for the first quarter of fiscal year 2023, and it ended on a date not specified in the provided context. However, based on the information about the sale of Gap China to Baozun Inc., which closed on January 31, 2023, we can infer that the first quarter of fiscal year 2023 likely ended around April 30, 2023.
#
#
# Question: What are the results for the reporting quarter? Please describe in the following order using bullet points - revenue, gross margin, opex, op margin, net income, and EPS. Include both GAAP and non-GAAP numbers. Please also include quarter-over-quarter changes.
#
# Answer: Here are the results for the reporting quarter:
#
# **Revenue:**
#
# * Net sales: $3,276 million (down 6% from last year's $3,477 million)
#
# **Gross Margin:**
#
# * GAAP gross margin: Not reported separately in the text.
# * Non-GAAP adjusted gross margin: Not reported in the text.
#
# **Opex:**
#
# * Operating expenses: $1,224 million (down 5% from last year's $1,293 million)
#
# **Op Margin:**
#
# * GAAP operating loss: $(10) million (improved from last year's $(197) million)
# * Non-GAAP adjusted operating income: $18 million (excluding a $47 million gain and $75 million of restructuring costs), with an adjusted operating margin of 0.5%.
#
# **Net Income:**
#
# * GAAP net loss: $(18) million (improved from last year's $(162) million)
# * Non-GAAP adjusted net income: $3 million (excluding the gain on sale and restructuring costs)
#
# **EPS:**
#
# * GAAP diluted loss per share: $(0.05) (improved from last year's $(0.44))
# * Non-GAAP adjusted diluted earnings per share: $0.01
#
#
# Question: If a municipality introduces a pay-as-you-throw program as part of its EPR strategy, charging households $0.05 per pound of collected waste, calculate the cost for a household that generates 30 pounds per week.
#
# Answer: I apologize, but this question is not related to the provided context. The context appears to be about Gap Inc.'s financial results and operations, whereas the question seems to be about a municipal program and waste management.
#
# If you could provide more information or clarify how this question relates to the context, I'd be happy to help.
#
#
# Question: What's the OP margin for the current quarter?
#
# Answer: According to the text, the company expects gross margin expansion in the second quarter and fiscal 2023 compared to the prior year. No specific operating profit (OP) margin is mentioned for the current quarter. However, it's stated that adjusted operating income was $18 million, excluding a $47 million gain related to the sale of an office building and $75 million of restructuring costs, resulting in an adjusted operating margin of 0.5%.
#
#
# Question: Identify potential risks associated with EPR implementation, such as regulatory changes, market volatility, and technological disruptions. Develop a risk assessment framework that assigns probabilities and impacts to each identified risk factor. Propose risk mitigation strategies for minimizing the adverse effects of these risks on EPR programs and stakeholder interests.
#
# Answer: Based on the provided context, I'll identify potential risks associated with EPR implementation, develop a risk assessment framework, and propose risk mitigation strategies.
#
# **Identified Risks:**
#
# 1. **Regulatory Changes**: Changes in laws, regulations, or policies that affect EPR programs.
# 2. **Market Volatility**: Fluctuations in market conditions, consumer behavior, or competitor actions that impact EPR sales and profitability.
# 3. **Technological Disruptions**: Disruptions or failures of technology systems, infrastructure, or tools used to support EPR programs.
# 4. **Supply Chain Disruptions**: Disruptions or failures of supply chain operations, including logistics, inventory management, or sourcing.
# 5. **Cybersecurity Threats**: Cyberattacks, data breaches, or other security incidents that compromise EPR program data or systems.
# 6. **Talent and Organizational Risks**: Insufficient skills, knowledge, or resources within the organization to effectively implement and manage EPR programs.
#
# **Risk Assessment Framework:**
#
# | Risk Factor | Probability (1-5) | Impact (1-5) | Risk Score |
# | --- | --- | --- | --- |
# | Regulatory Changes | 3 | 4 | 12 |
# | Market Volatility | 4 | 5 | 20 |
# | Technological Disruptions | 2 | 3 | 6 |
# | Supply Chain Disruptions | 3 | 4 | 12 |
# | Cybersecurity Threats | 4 | 5 | 20 |
# | Talent and Organizational Risks | 2 | 3 | 6 |
#
# **Risk Mitigation Strategies:**
#
# 1. **Regulatory Changes**:
# 	* Establish a regulatory monitoring program to track changes in laws, regulations, or policies.
# 	* Develop contingency plans for potential regulatory changes.
# 	* Engage with industry associations and advocacy groups to influence policy decisions.
# 2. **Market Volatility**:
# 	* Conduct regular market research and analysis to stay informed about consumer trends and competitor actions.
# 	* Develop flexible pricing strategies and inventory management systems to respond to market fluctuations.
# 	* Invest in data analytics tools to enhance forecasting and decision-making capabilities.
# 3. **Technological Disruptions**:
# 	* Implement robust IT infrastructure, including backup systems and disaster recovery plans.
# 	* Conduct regular security audits and penetration testing to identify vulnerabilities.
# 	* Develop partnerships with technology providers to ensure access to innovative solutions.
# 4. **Supply Chain Disruptions**:
# 	* Implement a multi-sourcing strategy to reduce dependence on single suppliers.
# 	* Develop contingency plans for potential supply chain disruptions.
# 	* Invest in supply chain visibility tools to enhance monitoring and response capabilities.
# 5. **Cybersecurity Threats**:
# 	* Implement robust cybersecurity measures, including encryption, firewalls, and access controls.
# 	* Conduct regular security training for employees and partners.
# 	* Engage with cybersecurity experts and industry associations to stay informed about emerging threats.
# 6. **Talent and Organizational Risks**:
# 	* Develop a comprehensive talent management program to attract, retain, and develop skilled professionals.
# 	* Establish clear roles, responsibilities, and communication channels within the organization.
# 	* Invest in training programs focused on EPR implementation, management, and analytics.
#
# By identifying potential risks, assessing their probabilities and impacts, and proposing risk mitigation strategies, organizations can proactively minimize the adverse effects of these risks on EPR programs and stakeholder interests.
#
#
# Question: What were Gap Inc's net sales for the first quarter of fiscal 2023 and how did they compare to the previous year?
#
# Answer: The text does not provide Gap Inc's total net sales for the first quarter of fiscal 2023. However, it provides net sales information for each of its brands: Old Navy, Gap, and Banana Republic.
#
# Here is the brand-level net sales information:
#
# * Old Navy: Net sales of $1.8 billion, down 1% compared to last year.
# * Gap: Net sales of $692 million, down 13% compared to last year. Excluding the negative impact from the sale of Gap China, the shutdown of Yeezy Gap, and foreign exchange headwinds, net sales were down 1% versus last year.
# * Banana Republic: Net sales of $432 million, down 10% on top of 24% growth last year.
#
# To get the total net sales for Gap Inc., you would need to add up these brand-level net sales figures.
#
#
# Question: How did merchandise margin change from the previous year, and what were the drivers of this change?
#
# Answer: The text does not provide information on how the merchandise margin changed from the previous year or what were the drivers of this change. The provided texts are more focused on sales performance, operating income, and other financial metrics. If you need more context or specific information, please let me know!
#
#
# Question: Did Gap Inc. have an operating profit or loss, and if so, what was the amount?
#
# Answer: According to the text, Gap Inc. had an operating loss of $10 million, with a reported operating margin of negative 0.3%. However, after excluding certain items such as a gain on the sale of an office building and restructuring costs, the company's adjusted operating income was $18 million, with an adjusted operating margin of 0.5%.
#
#
# Question: What were the key results from each of Gap Inc.'s brands (Old Navy, Gap, Banana Republic, and Athleta)?
#
# Answer: Based on the provided context, here are the key results for each of Gap Inc.'s brands:
#
# **Old Navy:**
#
# * Net sales: $1.8 billion, down 1% compared to last year.
# * Comparable sales: Down 1%.
# * Sales were driven by continued strength in women's categories, offset by softness in active and kid's categories, as well as slower demand from lower-income consumers.
#
# **Gap:**
#
# * Net sales: $692 million, down 13% compared to last year.
# * Excluding the negative impact of selling Gap China, shutting down Yeezy Gap, and foreign exchange headwinds, net sales were down 1% versus last year.
# * Comparable sales: Up 1%.
# * Sales were driven by continued strength in women's categories, offset by softness in active and kid's categories, as well as strategic store closures in North America.
#
# **Banana Republic:**
#
# * Net sales: $432 million, down 10% compared to last year (following 24% growth last year).
# * Comparable sales: Down 8%.
# * Sales were impacted as the brand lapped oversized growth last year driven by shifting consumer preferences.
#
# **Athleta:** (No specific results mentioned in the provided context.)
#
#
# Question: What is the company's outlook on net sales for the second quarter and the full fiscal year 2023?
#
# Answer: According to the text, the company expects net sales of $300 million in China and a positive impact of $150 million from a 53rd week in Fiscal 2023. Additionally, they anticipate gross margin expansion in the second quarter and full fiscal year 2023 compared to the prior year.
#
#
# Question: How much cash and cash equivalents did Gap, Inc. have at the end of the quarter?
#
# Answer: Gap, Inc. had $1.2 billion in cash and cash equivalents at the end of the quarter, which is an increase of 38% from the prior year.
#
#
# Question: How does the company expect gross margin to change in Q2 and the full year compared to 2022?
#
# Answer: According to the text, the company expects gross margin expansion in both the second quarter and fiscal 2023 compared to the prior year.
#
#
# Question: Did Gap Inc. pay a dividend in the first quarter, and what is their dividend strategy going forward?
#
# Answer: According to the text, Gap Inc. paid a first-quarter dividend of $0.15 per share, totaling $55 million. Additionally, the Board of Directors approved a second-quarter fiscal 2023 dividend of $0.15 per share. This suggests that Gap Inc. has a quarterly dividend strategy in place, with a consistent payout amount of $0.15 per share.
#
#
# Question: What are the key actions Gap Inc. is taking to execute its plan?
#
# Answer: Based on the provided context, it seems that the question is asking about the key actions Gap Inc. is taking to execute its plan, but there is no specific information in the text about the key actions.
#
# However, we can infer some information from the statements made by Bob Martin, Executive Chairman and Interim CEO, Gap Inc. He mentioned that they are "taking the necessary actions to drive critical change at Gap Inc., ultimately getting us back on a path toward delivering consistent results long-term." He also appreciated the employees for embracing a new operating model and organizational structure, a renewed focus on the customer, and for their continued belief in their incredible brands.
#
# So, we can assume that some of the key actions include:
#
# 1. Driving critical change across the organization.
# 2. Implementing a new operating model and organizational structure.
# 3. Renewed focus on the customer.
# 4. Embracing change and adapting to the new environment.
#
# Please note that these are inferred points and might not be exhaustive or entirely accurate without further information.

# %%
with open('answers.txt', 'w') as f:
    for ans in answers:
        f.write(f'{ans}\n')

# %% [markdown]
# ## Evaluation
#
# We use the ROGUE score for evaluation.

# %%
import evaluate

rouge = evaluate.load('rouge')

# %% [markdown]
# ### Reference answers from ChatGPT.
#
# The following answers were generated corresponding to each question using chat gpt 4. We compute the ROGUE score with respect these answers.

# %%
ref_answers = [
    ("""To meet the Extended Producer Responsibility (EPR) requirement of an 80% recovery target, the company should aim to recover 80% of its annual plastic production. If the company produces 500 tons of plastic packaging annually, then:

\[ \text{Recovery Target} = 500 \, \text{tons} \times 80\% = 400 \, \text{tons} \]

Thus, the company should aim to recover 400 tons of plastic packaging each year to meet the EPR requirement."""),
("""The report is for the first quarter of fiscal year 2023, and it ended on April 29, 2023."""),
("""Here are the results for Gap Inc. for the first quarter of fiscal 2023, including both GAAP and non-GAAP metrics along with the quarter-over-quarter changes:

- **Revenue (Net Sales):**
  - **GAAP:** $3.276 billion, down 6% compared to last year's $3.477 billion.

- **Gross Margin:**
  - **GAAP:** 37.1%, an increase from the previous year's 31.5%.
  - **Non-GAAP:** 37.2%, slightly higher than the GAAP figure.

- **Operating Expenses (OpEx):**
  - **GAAP:** $1.224 billion, representing 37.4% of net sales.
  - **Non-GAAP:** $1.200 billion, representing 36.6% of net sales.

- **Operating Margin (Op Margin):**
  - **GAAP:** -0.3%, improved from the previous year's -5.7%.
  - **Non-GAAP:** 0.5%, reflecting adjustments for restructuring costs and a gain on sale of a building.

- **Net Income:**
  - **GAAP:** Net loss of $18 million, improved from the previous year's net loss of $162 million.
  - **Non-GAAP:** Net income of $3 million, adjusted for the gain on sale and restructuring costs.

- **Earnings Per Share (EPS):**
  - **GAAP:** Net loss per share of $0.05, improved from the previous year's net loss per share of $0.44.
  - **Non-GAAP:** Earnings per share of $0.01, adjusted for the same factors as net income.

These results reflect improvements in gross margin and operating margin due to reduced operating expenses and other cost management efforts, despite the overall decline in revenue."""),
("""To calculate the cost for a household that generates 30 pounds of waste per week under a pay-as-you-throw program where the charge is $0.05 per pound, you would multiply the amount of waste by the cost per pound:

\[ \text{Weekly Cost} = 30 \, \text{pounds} \times \$0.05/\text{pound} \]

\[ \text{Weekly Cost} = \$1.50 \]

Therefore, the cost for a household generating 30 pounds of waste per week would be $1.50."""),
("""The operating margin (Op Margin) for Gap Inc. in the first quarter of fiscal 2023, based on the GAAP figures, was -0.3%."""),
("""Implementing an Extended Producer Responsibility (EPR) program can encounter various risks stemming from regulatory, economic, technological, and operational challenges. Below is a proposed risk assessment framework that categorizes risks, estimates their likelihood and potential impact, and suggests mitigation strategies.

### 1. **Risk Identification**

#### A. Regulatory Changes
- **Description:** Changes in national or regional waste management policies and regulations could affect the operational parameters or cost structures of EPR programs.
- **Probability:** Moderate
- **Impact:** High

#### B. Market Volatility
- **Description:** Fluctuations in the recycling market, such as changes in the value of recovered materials, can impact the cost-effectiveness of EPR schemes.
- **Probability:** High
- **Impact:** Medium

#### C. Technological Disruptions
- **Description:** New technologies in product design or waste management (like biodegradable materials or enhanced recycling techniques) could render current EPR processes obsolete.
- **Probability:** Low
- **Impact:** High

#### D. Non-Compliance by Stakeholders
- **Description:** Producers, consumers, or intermediaries might fail to comply with their roles and responsibilities defined by the EPR framework.
- **Probability:** Moderate
- **Impact:** Medium

#### E. Public Acceptance and Behavior Changes
- **Description:** Resistance or slow adoption by the public to EPR initiatives, such as increased sorting efforts or acceptance of pay-as-you-throw schemes.
- **Probability:** Moderate
- **Impact:** Medium

### 2. **Risk Assessment Matrix**

Here’s a simple matrix to visualize the risks:

| Risk Factor                  | Probability | Impact | Priority |
|------------------------------|-------------|--------|----------|
| Regulatory Changes           | Moderate    | High   | High     |
| Market Volatility            | High        | Medium | Medium   |
| Technological Disruptions    | Low         | High   | Medium   |
| Non-Compliance by Stakeholders | Moderate  | Medium | Medium   |
| Public Acceptance            | Moderate    | Medium | Medium   |

### 3. **Risk Mitigation Strategies**

#### A. Regulatory Changes
- **Strategy:** Develop flexible EPR programs that can quickly adapt to regulatory changes. Engage in policy discussions and advocacy to influence favorable regulatory environments.
- **Tools:** Regulatory watch groups, lobbying efforts.

#### B. Market Volatility
- **Strategy:** Diversify recycling options and materials recovered. Develop financial reserves or insurance mechanisms to handle market downturns.
- **Tools:** Hedging strategies, partnerships with diverse markets.

#### C. Technological Disruptions
- **Strategy:** Invest in research and development. Stay informed about technological trends and integrate adaptable, forward-looking practices in the EPR framework.
- **Tools:** Innovation labs, collaborations with tech companies.

#### D. Non-Compliance by Stakeholders
- **Strategy:** Implement robust monitoring and enforcement mechanisms. Educate stakeholders about the benefits and obligations under EPR.
- **Tools:** Compliance audits, educational programs.

#### E. Public Acceptance and Behavior Changes
- **Strategy:** Conduct awareness campaigns, incentivize participation, and make EPR-related processes user-friendly.
- **Tools:** Public relations campaigns, user experience enhancements in recycling processes.

### 4. **Implementation and Review**

Regularly reviewing and updating the risk management framework is crucial as market conditions, regulatory environments, and technology evolve. Continuous feedback loops and stakeholder engagement will also help refine the approach and ensure the EPR program's resilience against these identified risks."""),
("""Gap Inc.'s net sales for the first quarter of fiscal 2023 were $3.276 billion. This represented a 6% decrease compared to the previous year, where the net sales were $3.477 billion."""),
("""In the first quarter of fiscal 2023, Gap Inc.'s merchandise margin increased by 600 basis points compared to the previous year. This improvement was primarily driven by lower air freight expenses and improved promotional activity during the quarter. These factors helped to offset inflationary cost headwinds, contributing to the substantial improvement in merchandise margin."""),
("""Gap Inc. reported an operating loss of $10 million for the first quarter of fiscal 2023, as per the GAAP metrics. This was an improvement from the previous year, where the operating loss was significantly higher at $197 million."""),
("""Here are the key results for each of Gap Inc.'s brands in the first quarter of fiscal 2023:

- **Old Navy:**
  - **Net Sales:** $1.8 billion, a decrease of 1% compared to the previous year.
  - **Comparable Sales:** Decreased by 1%.
  - **Performance Drivers:** The slight decline in sales was driven by continued softness in the active and kids' categories, as well as slower demand from lower-income consumers, offset by strength in the women’s category.

- **Gap Brand:**
  - **Net Sales:** $692 million, down 13% compared to last year.
  - **Comparable Sales:** Increased by 1%.
  - **Performance Drivers:** Sales were primarily driven by strength in the women’s category, offset by continued softness in the active and kids' categories as well as strategic store closures in North America. The decrease in net sales was further influenced by the negative impact from the sale of Gap China and foreign exchange headwinds.

- **Banana Republic:**
  - **Net Sales:** $432 million, a decrease of 10% on top of a 24% growth in the previous year.
  - **Comparable Sales:** Down 8%.
  - **Performance Drivers:** The sales decrease was impacted as the brand lapped significant growth from the previous year, which was driven by a shift in consumer preferences.

- **Athleta:**
  - **Net Sales:** $321 million, down 11% compared to last year.
  - **Comparable Sales:** Decreased by 13%.
  - **Performance Drivers:** Sales in the quarter were impacted by continued product acceptance challenges.

These results reflect varying challenges and strategic responses across the brands, ranging from market positioning shifts to adjustments in product offerings and strategic management of store operations."""),
("""Gap Inc. provided the following outlook for net sales:

- **Second Quarter of Fiscal 2023:** The company estimates that net sales could decrease in the mid to high-single digit range compared to last year’s net sales of $3.86 billion. This estimate accounts for the sale of Gap China to Baozun Inc., which closed on January 31, 2023. The net sales for the second quarter of the previous year included approximately $60 million from Gap China.

- **Full Fiscal Year 2023:** Gap Inc. anticipates that net sales for the entire fiscal year could decrease in the low to mid-single digit range compared to last year’s net sales of $15.6 billion. The outlook for fiscal 2023 also includes the impact of an additional 53rd week, which is estimated to positively impact net sales by $150 million. This is in addition to adjustments accounting for the sale of Gap China, which contributed approximately $300 million to the fiscal 2022 net sales.

These projections reflect ongoing uncertainties in the consumer and macroeconomic environment, as well as strategic adjustments made by the company in response to these conditions."""),
("""At the end of the first quarter of fiscal 2023, Gap Inc. had cash and cash equivalents totaling $1.2 billion, which represented an increase of 38% from the prior year."""),
("""Gap Inc. expects gross margin expansion for both the second quarter and the full fiscal year of 2023 compared to the prior year. This anticipated improvement reflects the company's ongoing efforts to manage costs effectively and optimize its operations, despite the uncertain consumer and macroeconomic environment. This positive outlook on gross margin indicates a focus on improving profitability across their brand portfolio."""),
("""Yes, Gap Inc. paid a dividend in the first quarter of fiscal 2023. The company paid a first quarter dividend of $0.15 per share, totaling $55 million. Additionally, the Board of Directors approved a second quarter fiscal 2023 dividend of $0.15 per share. This continuation of dividend payments indicates that despite the financial challenges, Gap Inc. remains committed to returning value to its shareholders through dividends, which is part of their broader financial strategy."""),
("""Gap Inc. has outlined several key actions to execute its strategic plan aimed at driving critical change and improving business performance. These actions include:

1. **Optimizing Operating Model:** Gap Inc. is focusing on simplifying its operating model and organizational structure. This includes reducing complexity and costs, which is intended to make the company more agile and efficient.

2. **Enhancing Promotional Strategy:** The company is working on improving its promotional activities to better manage inventory levels and increase merchandise margin, as evidenced by the significant improvement in this area in the first quarter.

3. **Investing in Digital and Omni-channel Initiatives:** Gap Inc. continues to invest in its digital capabilities and omni-channel shopping experiences to bridge the gap between online and physical store shopping, enhancing overall customer experience.

4. **Store Optimization:** The company is strategically managing its store footprint by closing underperforming locations and optimizing the performance of others, contributing to better overall financial health.

5. **Focusing on Core Brands:** Gap Inc. is prioritizing investments in its core brands—Old Navy, Gap, Banana Republic, and Athleta—to strengthen their market positions and cater to consumer preferences effectively.

6. **Leadership and Organizational Changes:** Gap Inc. has been engaging in leadership changes, including the search for a new CEO, to bring fresh vision and drive to the company’s strategic initiatives.

7. **Customer-Centric Approach:** A renewed focus on understanding and responding to customer needs and preferences is central to Gap Inc.'s strategy, aiming to improve brand loyalty and attract new customers.

These actions are part of Gap Inc.'s broader efforts to position itself for sustainable, profitable growth and to enhance shareholder value over the long term.""")
    
]

# %%
results = rouge.compute(predictions=answers, references=ref_answers)
print(results)
# Out:
# {'rouge1': 0.4464043806898985, 'rouge2': 0.2593721963262924, 'rougeL': 0.34221814554954744, 'rougeLsum': 0.3828264431092137}

# %% [markdown]
# ## Fine tuning prompts

# %% [markdown]
# We finetune the prompt to make the answers more descriptive and informative. We also make the prompt such that the model address each part of the question
#  correctly.

# %%
template = """
Answer the question based on the context below. 
Provide a detailed, clear, and informative response.
Use simple language for clarity and ensure all parts of the query are addressed.

Context: {context}

Question: {question}
"""

prompt = PromptTemplate.from_template(template)
chain = (
    {
        "context": itemgetter("question") | retriever,
        "question": itemgetter("question"),
    }
    | prompt
    | model
    | parser
)

answers = []
for question in questions:
    ans = chain.invoke({'question': question})
    answers.append(ans)
    print(f"Question: {question}\n")
    print(f"Answer: {ans}")
    print('\n')
# Out:
# Question: A company produces 500 tons of plastic packaging annually and is subject to an Extended Producer Responsibility (EPR) scheme with a recovery target of 80%. How many tons of plastic packaging should the company aim to recover each year to meet the EPR requirement?
#
# Answer: Based on the provided context, let's calculate the required recovery amount:
#
# The company produces 500 tons of plastic packaging annually.
# The recovery target is 80% of the produced amount.
#
# To find the required recovery amount, multiply the production amount by the recovery target percentage:
# Recovery Amount = Production Amount x Recovery Target (%)
# = 500 tons x 0.8 (or 80%)
# = 400 tons
#
# Therefore, the company should aim to recover at least 400 tons of plastic packaging each year to meet the EPR requirement.
#
#
# Question: What is the report quarter and when did it end?
#
# Answer: The report is for the first quarter of fiscal year 2023, and it ended on April 29, 2023 (not explicitly mentioned in the text but can be inferred from the context).
#
#
# Question: What are the results for the reporting quarter? Please describe in the following order using bullet points - revenue, gross margin, opex, op margin, net income, and EPS. Include both GAAP and non-GAAP numbers. Please also include quarter-over-quarter changes.
#
# Answer: Here are the results for the reporting quarter:
#
# **Revenue:**
# * Net sales: $3,276 million (down from $3,477 million in the same quarter last year)
#
# **Gross Margin:**
# * GAAP gross margin: Not provided
# * Non-GAAP adjusted gross margin: Not provided (additional information is provided at the end of the press release along with a reconciliation of this measure)
#
# **Opex:**
# * Operating expenses: $1,224 million (down from $1,293 million in the same quarter last year)
#
# **Op Margin:**
# * GAAP operating loss: $(10) million (improved from $(197) million in the same quarter last year)
# * Non-GAAP adjusted operating income: $18 million (excluding a $47 million gain related to the sale of an office building and $75 million of restructuring costs); adjusted operating margin: 0.5%
#
# **Net Income:**
# * GAAP net loss: $(18) million (improved from $(162) million in the same quarter last year)
# * Non-GAAP adjusted net income: $3 million (excluding the gain on sale and restructuring costs)
#
# **EPS:**
# * GAAP diluted loss per share: $(0.05) (improved from $(0.44) in the same quarter last year)
# * Non-GAAP adjusted diluted earnings per share: $0.01
#
#
# Question: If a municipality introduces a pay-as-you-throw program as part of its EPR strategy, charging households $0.05 per pound of collected waste, calculate the cost for a household that generates 30 pounds per week.
#
# Answer: This question doesn't seem to be related to the provided context about Gap Inc.'s sales and financial results. However, I can still help you with the calculation.
#
# If a household generates 30 pounds of waste per week and is charged $0.05 per pound, the weekly cost would be:
#
# 30 pounds/week x $0.05/pound = $1.50/week
#
# To calculate the monthly or annual cost, you could multiply this weekly cost by 4 (for a month) or 52 (for a year), respectively.
#
# Let me know if you have any further questions!
#
#
# Question: What's the OP margin for the current quarter?
#
# Answer: According to the text, the company expects gross margin expansion in the second quarter and fiscal 2023 compared to the prior year. However, it does not provide a specific operating profit (OP) margin for the current quarter.
#
# If you're referring to the adjusted operating margin mentioned in the text, it's stated as 0.5% for the first quarter fiscal 2023.
#
#
# Question: Identify potential risks associated with EPR implementation, such as regulatory changes, market volatility, and technological disruptions. Develop a risk assessment framework that assigns probabilities and impacts to each identified risk factor. Propose risk mitigation strategies for minimizing the adverse effects of these risks on EPR programs and stakeholder interests.
#
# Answer: Based on the provided context, I'll identify potential risks associated with EPR implementation and develop a risk assessment framework.
#
# **Risk Identification:**
#
# 1. **Regulatory Changes**: Changes in laws, regulations, or industry standards affecting EPR programs.
# 2. **Market Volatility**: Fluctuations in market conditions, consumer behavior, or competitor actions impacting EPR sales and revenue.
# 3. **Technological Disruptions**: Interruptions or failures in technology infrastructure, data management, or cybersecurity affecting EPR operations.
# 4. **Supply Chain Disruptions**: Interruptions or disruptions in the supply chain, including material sourcing, manufacturing, and logistics.
# 5. **Stakeholder Expectations**: Unrealized stakeholder expectations regarding EPR performance, sustainability, or social responsibility.
# 6. **Data Management**: Inaccurate, incomplete, or insecure data management practices affecting EPR decision-making and reporting.
# 7. **Operational Inefficiencies**: Inefficient business processes, inadequate training, or insufficient resources hindering EPR implementation.
#
# **Risk Assessment Framework:**
#
# | Risk Factor | Probability (1-5) | Impact (1-5) | Risk Score |
# | --- | --- | --- | --- |
# | Regulatory Changes | 3 | 4 | 12 |
# | Market Volatility | 4 | 5 | 20 |
# | Technological Disruptions | 2 | 3 | 6 |
# | Supply Chain Disruptions | 3 | 4 | 12 |
# | Stakeholder Expectations | 4 | 5 | 20 |
# | Data Management | 2 | 3 | 6 |
# | Operational Inefficiencies | 3 | 4 | 12 |
#
# **Risk Mitigation Strategies:**
#
# 1. **Regulatory Changes**:
# 	* Establish a regulatory monitoring team to track changes and updates.
# 	* Develop contingency plans for potential regulatory changes.
# 	* Engage with industry associations and advocacy groups to influence policy decisions.
# 2. **Market Volatility**:
# 	* Conduct regular market research and analysis to anticipate trends and shifts.
# 	* Diversify revenue streams and product offerings to reduce dependence on a single market or customer segment.
# 	* Develop agile pricing and inventory management strategies to respond to changing market conditions.
# 3. **Technological Disruptions**:
# 	* Implement robust cybersecurity measures, including regular vulnerability assessments and penetration testing.
# 	* Develop disaster recovery plans and conduct regular backups of critical data.
# 	* Invest in cloud-based infrastructure and scalable technology solutions.
# 4. **Supply Chain Disruptions**:
# 	* Diversify suppliers and develop relationships with alternative vendors.
# 	* Implement just-in-time inventory management and real-time monitoring of supply chain operations.
# 	* Develop contingency plans for potential supply chain disruptions.
# 5. **Stakeholder Expectations**:
# 	* Engage in regular stakeholder communication and feedback mechanisms to understand expectations and concerns.
# 	* Develop transparent reporting and disclosure practices regarding EPR performance and progress.
# 	* Establish a stakeholder advisory board or committee to provide guidance and oversight.
# 6. **Data Management**:
# 	* Implement data governance policies and procedures to ensure accuracy, completeness, and security.
# 	* Conduct regular data quality assessments and remediation efforts.
# 	* Invest in advanced analytics and business intelligence tools to support EPR decision-making.
# 7. **Operational Inefficiencies**:
# 	* Conduct process mapping and optimization exercises to identify areas for improvement.
# 	* Develop training programs and provide resources to support employee development and efficiency.
# 	* Implement lean manufacturing principles and just-in-time production methods.
#
# By identifying potential risks, assessing their probability and impact, and developing mitigation strategies, organizations can minimize the adverse effects of these risks on EPR programs and stakeholder interests.
#
#
# Question: What were Gap Inc's net sales for the first quarter of fiscal 2023 and how did they compare to the previous year?
#
# Answer: Gap Inc's first-quarter fiscal 2023 results are not explicitly stated in the provided context. However, it does provide information on the individual brand performances.
#
# Old Navy's net sales were $1.8 billion, down 1% compared to last year.
# Gap's net sales were $692 million, down 13% compared to last year. Excluding the negative impact from the sale of Gap China, the shutdown of Yeezy Gap, and foreign exchange headwinds, net sales were down 1% versus last year.
# Banana Republic's net sales were $432 million, down 10% on top of 24% growth last year.
#
# To get the overall net sales for Gap Inc., we would need to add up the individual brand performances, but this information is not provided in the given context.
#
#
# Question: How did merchandise margin change from the previous year, and what were the drivers of this change?
#
# Answer: The provided text does not explicitly mention the change in merchandise margin or its drivers. However, it discusses sales performance for different brands, such as Old Navy, Gap, and Banana Republic, including net sales, comparable sales, and factors affecting their performance.
#
# If you're looking for information on merchandise margin, I recommend reviewing additional sections of the report or seeking out a separate document that specifically addresses this topic.
#
#
# Question: Did Gap Inc. have an operating profit or loss, and if so, what was the amount?
#
# Answer: Gap Inc. had an operating loss of $10 million, with a reported operating margin of negative 0.3%. However, when excluding a $47 million gain related to the sale of an office building and $75 million of restructuring costs, the adjusted operating income was $18 million, with an adjusted operating margin of 0.5%.
#
#
# Question: What were the key results from each of Gap Inc.'s brands (Old Navy, Gap, Banana Republic, and Athleta)?
#
# Answer: Based on the provided context, here are the key results for each of Gap Inc.'s brands:
#
# **Old Navy:**
#
# * Net sales: $1.8 billion, down 1% compared to last year.
# * Sales were driven by continued strength in the women's category, offset by softness in active and kids' categories as well as slower demand from lower-income consumers.
# * Comparable sales: down 1%.
#
# **Gap:**
#
# * Net sales: $692 million, down 13% compared to last year.
# * Excluding the negative impact of the sale of Gap China, shutdown of Yeezy Gap, and foreign exchange headwinds, net sales were down 1% versus last year, driven by strength in women's category offset by softness in active and kids' categories as well as strategic store closures in North America.
# * Comparable sales: up 1%.
#
# **Banana Republic:**
#
# * Net sales: $432 million, down 10% on top of 24% growth last year.
# * Sales were impacted as the brand lapped outsized growth last year driven by a shift in consumer preferences.
# * Comparable sales: down 8%.
#
# **Athleta:**
#
# * No specific results mentioned for Athleta in the provided context.
#
#
# Question: What is the company's outlook on net sales for the second quarter and the full fiscal year 2023?
#
# Answer: According to the text, the company expects net sales to be positively impacted by $150 million due to a 53rd week in fiscal 2023. This suggests that the company's outlook is positive, with an expected increase in net sales for both the second quarter and the full fiscal year 2023.
#
#
# Question: How much cash and cash equivalents did Gap, Inc. have at the end of the quarter?
#
# Answer: Gap, Inc. had $1.2 billion in cash and cash equivalents at the end of the quarter, which is an increase of 38% from the prior year.
#
#
# Question: How does the company expect gross margin to change in Q2 and the full year compared to 2022?
#
# Answer: According to the text, the company expects gross margin expansion in both the second quarter (Q2) and fiscal year 2023 compared to the prior year.
#
#
# Question: Did Gap Inc. pay a dividend in the first quarter, and what is their dividend strategy going forward?
#
# Answer: According to the text, Gap Inc. paid a dividend of $0.15 per share, totaling $55 million, in the first quarter of fiscal 2023. Additionally, the Board of Directors approved a second-quarter fiscal 2023 dividend of $0.15 per share. This suggests that Gap Inc.'s current dividend strategy is to pay a quarterly dividend of $0.15 per share.
#
#
# Question: What are the key actions Gap Inc. is taking to execute its plan?
#
# Answer: Based on the provided context, it appears that Gap Inc. is taking several key actions to execute its plan, including:
#
# 1. **Simplifying and optimizing its operating model and structure**: The company is making changes to its organizational structure to drive critical change and improve results.
#
# 2. **Focusing on customers**: Gap Inc. is renewing its focus on customers, which suggests an emphasis on improving customer experiences and building brand loyalty.
#
# 3. **Reducing inventory**: The company is working to reduce its inventory levels, likely to improve efficiency, reduce waste, and better match supply with demand.
#
# 4. **Delivering improvements to the business**: Gap Inc. is focused on delivering tangible results, including share gains at Old Navy and Gap Brand, adjusted operating margin expansion, and strength in its balance sheet.
#
# 5. **Embracing a new operating model**: The company's employees are embracing a new way of working, which implies cultural and process changes aimed at driving lasting change and improvement.
#
# These actions suggest that Gap Inc. is committed to transforming its business to achieve long-term success.

# %% [markdown]
# ## Evaluation with refined query
#
# We observe that the ROGUE score increases with a refined query.

# %%
results = rouge.compute(predictions=answers, references=ref_answers)
print(results)
# Out:
# {'rouge1': 0.5011824089897023, 'rouge2': 0.295185216930167, 'rougeL': 0.366529519687461, 'rougeLsum': 0.4335285657162302}
